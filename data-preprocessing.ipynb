# %% [markdown]
# ## Load data

# %%
trainval <- read.csv('train-set-values.csv')
trainlab <- read.csv('train-set-labels.csv')
train <- merge(trainlab,trainval,by='id')
head(train)
# Out:
#   id status_group   amount_tsh date_recorded funder          gps_height
# 1 0  non functional  0         2012-11-13    Tasaf              0
# 2 1  functional      0         2011-03-05    Shipo           1978
# 3 2  functional      0         2011-03-27    Lvia               0
# 4 3  functional     10         2013-06-03    Germany Republi 1639
# 5 4  non functional  0         2011-03-22    Cmsr               0
# 6 5  functional     50         2011-02-26    Private           28
#   installer longitude latitude  wpt_name       ... payment_type water_quality
# 1 TASAF     33.12583  -5.118154 Mratibu        ... unknown      milky
# 2 SHIPO     34.77072  -9.395642 none           ... never pay    soft
# 3 LVIA      36.11506  -6.279268 Bombani        ... per bucket   soft
# 4 CES       37.14743  -3.187555 Area 7 Namba 5 ... per bucket   soft
# 5 CMSR      36.16489  -6.099289 Ezeleda        ... unknown      soft
# 6 Private   39.28612  -6.972403 Kwa Namaj      ... per bucket   soft
#   quality_group quantity     quantity_group source       source_type
# 1 milky         enough       enough         shallow well shallow well
# 2 good          enough       enough         shallow well shallow well
# 3 good          insufficient insufficient   machine dbh  borehole
# 4 good          enough       enough         spring       spring
# 5 good          dry          dry            shallow well shallow well
# 6 good          enough       enough         machine dbh  borehole
#   source_class waterpoint_type             waterpoint_type_group
# 1 groundwater  hand pump                   hand pump
# 2 groundwater  hand pump                   hand pump
# 3 groundwater  communal standpipe multiple communal standpipe
# 4 groundwater  communal standpipe          communal standpipe
# 5 groundwater  hand pump                   hand pump
# 6 groundwater  communal standpipe multiple communal standpipe

# %%
summary(train)
# Out:
#        id                         status_group     amount_tsh
#  Min.   :    0   functional             :32259   Min.   :     0.0
#  1st Qu.:18520   functional needs repair: 4317   1st Qu.:     0.0
#  Median :37062   non functional         :22824   Median :     0.0
#  Mean   :37115                                   Mean   :   317.7
#  3rd Qu.:55657                                   3rd Qu.:    20.0
#  Max.   :74247                                   Max.   :350000.0
#
#     date_recorded                      funder        gps_height
#  2011-03-15:  572   Government Of Tanzania: 9084   Min.   : -90.0
#  2011-03-17:  558                         : 3635   1st Qu.:   0.0
#  2013-02-03:  546   Danida                : 3114   Median : 369.0
#  2011-03-14:  520   Hesawa                : 2202   Mean   : 668.3
#  2011-03-16:  513   Rwssp                 : 1374   3rd Qu.:1319.2
#  2011-03-18:  497   World Bank            : 1349   Max.   :2770.0
#  (Other)   :56194   (Other)               :38642
#       installer       longitude        latitude            wpt_name
#  DWE       :17402   Min.   : 0.00   Min.   :-11.649   none     : 3563
#            : 3655   1st Qu.:33.09   1st Qu.: -8.541   Shuleni  : 1748
#  Government: 1825   Median :34.91   Median : -5.022   Zahanati :  830
#  RWE       : 1206   Mean   :34.08   Mean   : -5.706   Msikitini:  535
#  Commu     : 1060   3rd Qu.:37.18   3rd Qu.: -3.326   Kanisani :  323
#  DANIDA    : 1050   Max.   :40.35   Max.   :  0.000   Bombani  :  271
#  (Other)   :33202                                     (Other)  :52130
#   num_private                    basin          subvillage
#  Min.   :   0.0000   Lake Victoria  :10248   Madukani:  508
#  1st Qu.:   0.0000   Pangani        : 8940   Shuleni :  506
#  Median :   0.0000   Rufiji         : 7976   Majengo :  502
#  Mean   :   0.4741   Internal       : 7785   Kati    :  373
#  3rd Qu.:   0.0000   Lake Tanganyika: 6432           :  371
#  Max.   :1776.0000   Wami / Ruvu    : 5987   Mtakuja :  262
#                      (Other)        :12032   (Other) :56878
#          region       region_code   district_code             lga
#  Iringa     : 5294   Min.   : 1.0   Min.   : 0.00   Njombe      : 2503
#  Shinyanga  : 4982   1st Qu.: 5.0   1st Qu.: 2.00   Arusha Rural: 1252
#  Mbeya      : 4639   Median :12.0   Median : 3.00   Moshi Rural : 1251
#  Kilimanjaro: 4379   Mean   :15.3   Mean   : 5.63   Bariadi     : 1177
#  Morogoro   : 4006   3rd Qu.:17.0   3rd Qu.: 5.00   Rungwe      : 1106
#  Arusha     : 3350   Max.   :99.0   Max.   :80.00   Kilosa      : 1094
#  (Other)    :32750                                  (Other)     :51017
#         ward         population      public_meeting
#  Igosi    :  307   Min.   :    0.0        : 3334
#  Imalinyi :  252   1st Qu.:    0.0   False: 5055
#  Siha Kati:  232   Median :   25.0   True :51011
#  Mdandu   :  231   Mean   :  179.9
#  Nduruma  :  217   3rd Qu.:  215.0
#  Kitunda  :  203   Max.   :30500.0
#  (Other)  :57958
#                   recorded_by          scheme_management        scheme_name
#  GeoData Consultants Ltd:59400   VWC            :36793                :28166
#                                  WUG            : 5206   K            :  682
#                                                 : 3877   None         :  644
#                                  Water authority: 3153   Borehole     :  546
#                                  WUA            : 2883   Chalinze wate:  405
#                                  Water Board    : 2748   M            :  400
#                                  (Other)        : 4740   (Other)      :28557
#    permit      construction_year    extraction_type  extraction_type_group
#       : 3056   Min.   :   0      gravity    :26780   gravity    :26780
#  False:17492   1st Qu.:   0      nira/tanira: 8154   nira/tanira: 8154
#  True :38852   Median :1986      other      : 6430   other      : 6430
#                Mean   :1301      submersible: 4764   submersible: 6179
#                3rd Qu.:2004      swn 80     : 3670   swn 80     : 3670
#                Max.   :2013      mono       : 2865   mono       : 2865
#                                  (Other)    : 6737   (Other)    : 5322
#   extraction_type_class            management      management_group
#  gravity     :26780     vwc             :40507   commercial: 3638
#  handpump    :16456     wug             : 6515   other     :  943
#  motorpump   : 2987     water board     : 2933   parastatal: 1768
#  other       : 6430     wua             : 2535   unknown   :  561
#  rope pump   :  451     private operator: 1971   user-group:52490
#  submersible : 6179     parastatal      : 1768
#  wind-powered:  117     (Other)         : 3171
#                   payment          payment_type           water_quality
#  never pay            :25348   annually  : 3642   soft           :50818
#  other                : 1054   monthly   : 8300   salty          : 4856
#  pay annually         : 3642   never pay :25348   unknown        : 1876
#  pay monthly          : 8300   on failure: 3914   milky          :  804
#  pay per bucket       : 8985   other     : 1054   coloured       :  490
#  pay when scheme fails: 3914   per bucket: 8985   salty abandoned:  339
#  unknown              : 8157   unknown   : 8157   (Other)        :  217
#   quality_group           quantity          quantity_group
#  colored :  490   dry         : 6246   dry         : 6246
#  fluoride:  217   enough      :33186   enough      :33186
#  good    :50818   insufficient:15129   insufficient:15129
#  milky   :  804   seasonal    : 4050   seasonal    : 4050
#  salty   : 5195   unknown     :  789   unknown     :  789
#  unknown : 1876
#
#                   source                    source_type         source_class
#  spring              :17021   borehole            :11949   groundwater:45794
#  shallow well        :16824   dam                 :  656   surface    :13328
#  machine dbh         :11075   other               :  278   unknown    :  278
#  river               : 9612   rainwater harvesting: 2295
#  rainwater harvesting: 2295   river/lake          :10377
#  hand dtw            :  874   shallow well        :16824
#  (Other)             : 1699   spring              :17021
#                     waterpoint_type         waterpoint_type_group
#  cattle trough              :  116   cattle trough     :  116
#  communal standpipe         :28522   communal standpipe:34625
#  communal standpipe multiple: 6103   dam               :    7
#  dam                        :    7   hand pump         :17488
#  hand pump                  :17488   improved spring   :  784
#  improved spring            :  784   other             : 6380
#  other                      : 6380

# %%
test <- read.csv('test-set-values.csv')

# %% [markdown]
# ## Select predictor variables

# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### Choose variables that have an impact on waterpoint functionality

# %%
train <- train[, which(names(train) %in% c('status_group','amount_tsh','gps_height','installer','basin','population','public_meeting','scheme_management','permit','construction_year','extraction_type','management','payment_type','water_quality','quantity_group','source_class','waterpoint_type'))]
test <- test[, which(names(test) %in% c('amount_tsh','gps_height','installer','basin','population','public_meeting','scheme_management','permit','construction_year','extraction_type','management','payment_type','water_quality','quantity_group','source_class','waterpoint_type'))]

# %% [markdown]
# ### Reduce factor levels for variables with many factor levels

# %%
train %>% group_by(installer) %>% summarise(totals = n())
summary(train$installer)
# Out:
#      installer             totals
# 1                          3655
# 2    -                        3
# 3    0                      777
# 4    A.D.B                    1
# 5    AAR                      4
# 6    Aartisa                  1
# 7    ABASIA                  29
# 8    ABD                      1
# 9    ABDALA                   1
# 10   Abdallah Ally Wazir      1
# 11   ABDUL                    1
# 12   AC                       2
# 13   Accra                   30
# 14   ACORD                    3
# 15   ACRA                   278
# 16   ACT                      1
# 17   ACT MARA                 1
# 18   Action Aid               1
# 19   ACTION AID               1
# 20   Action Contre la Faim    1
# 21   Action Contre La Faim    8
# 22   Active KMK               1
# 23   Active MKM              26
# 24   ACTIVE TANK CO           9
# 25   ACTIVE TANK CO LTD       2
# 26   AD                      14
# 27   Adam                     2
# 28   Adam Kea                 1
# 29   Adam mualuaka            1
# 30   ADAP                     4
# ...  ...                   ...
# 2117 WORLD VISION           20
# 2118 World Vission          12
# 2119 WOULD BANK             13
# 2120 WOYEGE                  1
# 2121 WSDP                   13
# 2122 WSSP                    1
# 2123 WU                    301
# 2124 WUA                     8
# 2125 WUS                     1
# 2126 WVC                     3
# 2127 WVT                   158
# 2128 WW                      1
# 2129 WWF                    23
# 2130 WWF/                    1
# 2131 Yakwetu Contractor      1
# 2132 Yasini                  1
# 2133 Yasini Selemani         1
# 2134 YEBE CHIKOMESH          3
# 2135 YELL LTD                2
# 2136 Yohanis Mgaya           1
# 2137 Yoroko mwalongo         1
# 2138 YUMBAKA ENGINEERING     6
# 2139 Zaburi and neighbors    1
# 2140 Zacharia MTN            4
# 2141 Zao                     1
# 2142 Zao water spring        3
# 2143 Zao water spring X      1
# 2144 ZINDUKA                 1
# 2145 Zingibali Secondary     1
# 2146 Zuber Mihungo           1
#                           DWE
#                         17402                          3655
#                    Government                           RWE
#                          1825                          1206
#                         Commu                        DANIDA
#                          1060                          1050
#                          KKKT                        Hesawa
#                           898                           840
#                             0                          TCRS
#                           777                           707
#            Central government                           CES
#                           622                           610
#                     Community                         DANID
#                           553                           552
#              District Council                        HESAWA
#                           551                           539
#                           LGA                  World vision
#                           408                           408
#                        WEDECO                         TASAF
#                           397                           396
#              District council                         Gover
#                           392                           383
#                         AMREF                         TWESA
#                           329                           316
#                            WU                          Dmdd
#                           301                           287
#                          ACRA                  World Vision
#                           278                           270
#                          SEMA                            DW
#                           249                           246
#                         OXFAM                            Da
#                           234                           224
#                          Gove                 Idara ya maji
#                           222                           222
#                        UNICEF    Sengerema Water Department
#                           222                           214
#                     Kiliwater                          FinW
#                           210                           208
#                         NORAD                            DH
#                           208                           202
#                     Villagers                          DWSP
#                           199                           192
#                        Distri          Lawatefuka water sup
#                           181                           180
#          Magadini-Makiwaru wa                            RC
#                           175                           174
#                            FW          KKKT _ Konde and DWE
#                           173                           166
#                         Centr                           WVT
#                           162                           158
#                           MWE           Handeni Trunk Main(
#                           157                           156
#                            Is                         Norad
#                           154                           152
#                    Fini Water                         RWSSP
#                           149                           149
#                         SHIPO                       Private
#                           147                           143
#                        Kuwait                         JAICA
#                           142                           141
#                  Central govt                       Artisan
#                           138                           135
#                           ISF                    Fini water
#                           135                           133
#                         GOVER                          DDCA
#                           128                           126
#                            HE                     RC CHURCH
#                           125                           125
#                         Tardo                       Mission
#                           123                           121
#                         World                            Ir
#                           121                           119
#                      wananchi           Consulting Engineer
#                           119                           116
#                         Amref                          JICA
#                           114                           113
#                           TWE            Central Government
#                           111                           110
#                         MUWSA                           DED
#                           107                           105
#                    FINI WATER                     WATER AID
#                           103                           103
# Halmashauri ya wilaya sikonge                           HSW
#                           102                           100
#                Wizara ya maji                         Jaica
#                           100                            98
#                        Unisef                            Go
#                            98                            97
#                            Ki                        OXFARM
#                            97                            96
#                    World Bank                         Roman
#                            95                            94
#                         Angli                           VWC
#                            92                            91
#     District water department                          DMDD
#                            89                            89
#                         Missi                             H
#                            87                            86
#                         Shipo                       (Other)
#                            86                         12250

# %%
# Reword values for values that were represented in different formats
change_var <- function(table){
  table$installer <- tolower(table$installer)
  table$installer[table$installer == 'central government'] <- 'government'
  table$installer[table$installer == 'central govt'] <- 'government'
  table$installer[table$installer == 'centr'] <- 'government'
  table$installer[table$installer == 'gove'] <- 'government'
  table$installer[table$installer == 'gover'] <- 'government'
  table$installer[table$installer == 'distri'] <- 'district council'
  table$installer[table$installer == 'counc'] <- 'district council'
  table$installer[table$installer == 'council'] <- 'district council'
  table$installer[table$installer == 'district water department'] <- 'district council'
  table$installer[table$installer == 'commu'] <- 'community'
  table$installer[table$installer == 'commu'] <- 'community'
  table$installer[table$installer == 'adra /community'] <- 'adra'
  table$installer[table$installer == 'adra/ Community'] <- 'adra'
  table$installer[table$installer == 'adra/government'] <- 'adra'
  table$installer[table$installer == 'adra /government'] <- 'adra'
  table$installer[table$installer == 'adra/community'] <- 'adra'
  table$installer[table$installer == 'world vission'] <- 'world vision'
  table$installer[table$installer == 'danid'] <- 'danida'
  return(table)
}
train <- change_var(train)
test <- change_var(test)

# note: this is a non-exhaustive list. I tried to identify as many values as possible

# %%
# Select the top 16 values and change the rest to "others"
train$installer[train$installer %in% c(" ", "", "0", "_", "-")] <- "other"
installer_top <- names(summary(as.factor(train$installer)))[1:15]
train$installer[!(train$installer %in% installer_top)] <- "other"
table(train$installer, train$status_group)

test$installer[test$installer %in% c(" ", "", "0", "_", "-")] <- "other"
installer_top <- names(summary(as.factor(test$installer)))[1:15]
test$installer[!(test$installer %in% installer_top)] <- "other"
# Out:
#
#                    functional functional needs repair non functional
#   amref                   189                       6            248
#   ces                     538                       1             71
#   community              1113                      73            434
#   danida                 1037                      95            542
#   district council        502                      99            721
#   dwe                    9434                    1622           6349
#   government             1195                     322           2170
#   hesawa                  786                      54            555
#   kkkt                    425                      62            423
#   lga                     105                      81            227
#   other                 15904                    1634           9771
#   rwe                     304                     137            765
#   tcrs                    290                      42            375
#   world vision            437                      89            173

# %%
# extraction_type: 'other - mkulima/shinyanga' does not exist in test set but 'other' does
train$extraction_type[train$extraction_type=='other - mkulima/shinyanga'] <- 'other'
train$extraction_type <- factor(as.character(train$extraction_type))

# %% [markdown]
# ## Save train and test to CSV files

# %%
write.csv(train, "myTrainT.csv", row.names=FALSE)
write.csv(test, "myTestT.csv", row.names=FALSE)
